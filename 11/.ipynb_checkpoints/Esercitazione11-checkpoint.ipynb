# %% [markdown]
# # Esercitazione 11 - Regressione con reti neurali

# %% [markdown]
# ## 1 Obiettivo

# %% [markdown]
# L'obiettivo di questa esercitazione è utilizzare delle reti neurali come strumento per eseguire una regressione. Verranno studiate le potenzialità è i limiti di questo strumento e la dipendenza dei risultati dalla struttura della rete neurale.

# %% [markdown]
# ## 2 Implementazione

# %% [markdown]
# Per l'implementazione del codice utilizzato nel corso di questa esercitazione verrà utilizzata la libreria Keras fornita con tensorflow.
#
# L'implementazione seguirà i seguenti step:
# - generazione dei dati divisi in training set e validation set
# - scelta degli iperparametri che definiscono la struttura della rete neurale
# - preparazione del modello di rete neurale
# - compilazione ed esecuzione del modello
# - salvataggio dei risultati ottenuti
#
# I dati da elaborare sono costituiti da coppie di valori $(x,y)$. L'obiettivo della rete neurale è quello di effettuare una regressione, ovvero determinare una funzione $f$ tale che $y=f(x)$. In questo caso la $f$ corrisponde all'azione dell'intera rete allenata sul valore di x, in altre parole deve essere possibile predirre il valore di y dato quello della x corrispondente.
#
# In questo caso, essendo una implementazione atta a studiare lo strumento, le coppie $(x,y)$ vengono generate partendo da una forma funzionale $y=f(x)$ nota. Viene inoltre aggiunto alla y un rumore gaussiano caratterizzato da una specifica deviazione standard `sigma`:
# $$
#     y = f(x) + N(0, \sigma)
# $$

# %% [markdown]
# ## 3 Codice

# %% [markdown]
# Import necessari

# %%
import os
import json

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

# %% [markdown]
# Impostazione degli iperparametri

# %%
para = {
    'n_hidden_layers' : 2,
    'n_neurons_per_layer' : 16,
    'activation_function' : 'relu',
    'opt' : 'adam',
    'loss_function' : 'mse',

    'sigma' : 0.1,
    'n_epochs' : 500,
    'n_train_data' : 500,
    'n_valid_data' : 50,

    'simulation_name' : 'es2test17'}

# %% [markdown]
# Generazione dei set di dati

# %%
def target_function_es1(x):
    return 2*x + 1

def target_function_es2(x):
    return 4 - 3*x -2*(x**2) + 3*(x**3)

np.random.seed(0)

x_train = np.random.uniform(-1, 1, para['n_train_data'])
x_valid = np.random.uniform(-1, 1, para['n_valid_data'])
x_valid.sort()

y_target =  target_function_es2(x_valid)
y_train = np.random.normal(target_function_es2(x_train), para['sigma'])
y_valid = np.random.normal(y_target, para['sigma'])

# %% [markdown]
# Mostro i dati che ho generato

# %%
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data', marker='.')
plt.legend()
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Preparo il modello

# %%
model = tf.keras.Sequential()

#layer di input 
model.add(Dense(1, input_shape=(1,), activation=para['activation_function']))

#hidden layers
for i in range(0, para['n_hidden_layers']):
        model.add(Dense(para['n_neurons_per_layer'], activation=para['activation_function']))
        
#layer di output
model.add(Dense(1))

# %% [markdown]
# Mostro un sommario del modello che ho costruito. Viene anche indicato il numero di parametri della rete che verranno allenati.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_9 (Dense)              (None, 16)                32
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 323
# Trainable params: 323
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compilo il modello e lo eseguo

# %%
model.compile(optimizer=para['opt'], loss=para['loss_function'], metrics=['mse'])
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=para['n_epochs'],
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/500
# 16/16 [==============================] - 0s 8ms/step - loss: 12.1259 - mse: 12.1259 - val_loss: 12.0017 - val_mse: 12.0017
# Epoch 2/500
# 16/16 [==============================] - 0s 2ms/step - loss: 11.8282 - mse: 11.8282 - val_loss: 11.6815 - val_mse: 11.6815
# Epoch 3/500
# 16/16 [==============================] - 0s 2ms/step - loss: 11.4856 - mse: 11.4856 - val_loss: 11.2985 - val_mse: 11.2985
# Epoch 4/500
# 16/16 [==============================] - 0s 3ms/step - loss: 11.0698 - mse: 11.0698 - val_loss: 10.8486 - val_mse: 10.8486
# Epoch 5/500
# 16/16 [==============================] - 0s 3ms/step - loss: 10.5925 - mse: 10.5925 - val_loss: 10.3351 - val_mse: 10.3351
# Epoch 6/500
# 16/16 [==============================] - 0s 3ms/step - loss: 10.0482 - mse: 10.0482 - val_loss: 9.7400 - val_mse: 9.7400
# Epoch 7/500
# 16/16 [==============================] - 0s 3ms/step - loss: 9.4164 - mse: 9.4164 - val_loss: 9.0446 - val_mse: 9.0446
# Epoch 8/500
# 16/16 [==============================] - 0s 3ms/step - loss: 8.6667 - mse: 8.6667 - val_loss: 8.2049 - val_mse: 8.2049
# Epoch 9/500
# 16/16 [==============================] - 0s 3ms/step - loss: 7.7359 - mse: 7.7359 - val_loss: 7.1671 - val_mse: 7.1671
# Epoch 10/500
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5978 - mse: 6.5978 - val_loss: 5.8943 - val_mse: 5.8943
# Epoch 11/500
# 16/16 [==============================] - 0s 3ms/step - loss: 5.2432 - mse: 5.2432 - val_loss: 4.5021 - val_mse: 4.5021
# Epoch 12/500
# 16/16 [==============================] - 0s 3ms/step - loss: 3.8314 - mse: 3.8314 - val_loss: 3.1283 - val_mse: 3.1283
# Epoch 13/500
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5227 - mse: 2.5227 - val_loss: 1.9900 - val_mse: 1.9900
# Epoch 14/500
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5133 - mse: 1.5133 - val_loss: 1.2388 - val_mse: 1.2388
# Epoch 15/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9146 - mse: 0.9146 - val_loss: 0.8812 - val_mse: 0.8812
# Epoch 16/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6471 - mse: 0.6471 - val_loss: 0.7919 - val_mse: 0.7919
# Epoch 17/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5830 - mse: 0.5830 - val_loss: 0.7924 - val_mse: 0.7924
# Epoch 18/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5708 - mse: 0.5708 - val_loss: 0.8014 - val_mse: 0.8014
# Epoch 19/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5691 - mse: 0.5691 - val_loss: 0.8036 - val_mse: 0.8036
# Epoch 20/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5681 - mse: 0.5681 - val_loss: 0.8056 - val_mse: 0.8056
# Epoch 21/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5662 - mse: 0.5662 - val_loss: 0.8078 - val_mse: 0.8078
# Epoch 22/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5650 - mse: 0.5650 - val_loss: 0.8122 - val_mse: 0.8122
# Epoch 23/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5643 - mse: 0.5643 - val_loss: 0.8127 - val_mse: 0.8127
# Epoch 24/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5650 - mse: 0.5650 - val_loss: 0.8085 - val_mse: 0.8085
# Epoch 25/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5634 - mse: 0.5634 - val_loss: 0.8135 - val_mse: 0.8135
# Epoch 26/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5624 - mse: 0.5624 - val_loss: 0.8108 - val_mse: 0.8108
# Epoch 27/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5603 - mse: 0.5603 - val_loss: 0.8100 - val_mse: 0.8100
# Epoch 28/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5593 - mse: 0.5593 - val_loss: 0.8076 - val_mse: 0.8076
# Epoch 29/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5575 - mse: 0.5575 - val_loss: 0.8079 - val_mse: 0.8079
# Epoch 30/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5564 - mse: 0.5564 - val_loss: 0.8041 - val_mse: 0.8041
# Epoch 31/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5537 - mse: 0.5537 - val_loss: 0.8063 - val_mse: 0.8063
# Epoch 32/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5520 - mse: 0.5520 - val_loss: 0.8016 - val_mse: 0.8016
# Epoch 33/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5504 - mse: 0.5504 - val_loss: 0.7981 - val_mse: 0.7981
# Epoch 34/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5482 - mse: 0.5482 - val_loss: 0.7965 - val_mse: 0.7965
# Epoch 35/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5460 - mse: 0.5460 - val_loss: 0.7891 - val_mse: 0.7891
# Epoch 36/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5424 - mse: 0.5424 - val_loss: 0.7889 - val_mse: 0.7889
# Epoch 37/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5399 - mse: 0.5399 - val_loss: 0.7841 - val_mse: 0.7841
# Epoch 38/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5366 - mse: 0.5366 - val_loss: 0.7835 - val_mse: 0.7835
# Epoch 39/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5343 - mse: 0.5343 - val_loss: 0.7753 - val_mse: 0.7753
# Epoch 40/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5301 - mse: 0.5301 - val_loss: 0.7738 - val_mse: 0.7738
# Epoch 41/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5274 - mse: 0.5274 - val_loss: 0.7705 - val_mse: 0.7705
# Epoch 42/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5239 - mse: 0.5239 - val_loss: 0.7623 - val_mse: 0.7623
# Epoch 43/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5193 - mse: 0.5193 - val_loss: 0.7623 - val_mse: 0.7623
# Epoch 44/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5153 - mse: 0.5153 - val_loss: 0.7549 - val_mse: 0.7549
# Epoch 45/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5107 - mse: 0.5107 - val_loss: 0.7460 - val_mse: 0.7460
# Epoch 46/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5070 - mse: 0.5070 - val_loss: 0.7419 - val_mse: 0.7419
# Epoch 47/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5052 - mse: 0.5052 - val_loss: 0.7392 - val_mse: 0.7392
# Epoch 48/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5018 - mse: 0.5018 - val_loss: 0.7222 - val_mse: 0.7222
# Epoch 49/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4925 - mse: 0.4925 - val_loss: 0.7287 - val_mse: 0.7287
# Epoch 50/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4884 - mse: 0.4884 - val_loss: 0.7205 - val_mse: 0.7205
# Epoch 51/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4818 - mse: 0.4818 - val_loss: 0.7076 - val_mse: 0.7076
# Epoch 52/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4775 - mse: 0.4775 - val_loss: 0.7093 - val_mse: 0.7093
# Epoch 53/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4709 - mse: 0.4709 - val_loss: 0.6938 - val_mse: 0.6938
# Epoch 54/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4648 - mse: 0.4648 - val_loss: 0.6873 - val_mse: 0.6873
# Epoch 55/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4587 - mse: 0.4587 - val_loss: 0.6765 - val_mse: 0.6765
# Epoch 56/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4581 - mse: 0.4581 - val_loss: 0.6697 - val_mse: 0.6697
# Epoch 57/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4484 - mse: 0.4484 - val_loss: 0.6691 - val_mse: 0.6691
# Epoch 58/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4411 - mse: 0.4411 - val_loss: 0.6492 - val_mse: 0.6492
# Epoch 59/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4331 - mse: 0.4331 - val_loss: 0.6433 - val_mse: 0.6433
# Epoch 60/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4273 - mse: 0.4273 - val_loss: 0.6321 - val_mse: 0.6321
# Epoch 61/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4200 - mse: 0.4200 - val_loss: 0.6256 - val_mse: 0.6256
# Epoch 62/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4116 - mse: 0.4116 - val_loss: 0.6093 - val_mse: 0.6093
# Epoch 63/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4052 - mse: 0.4052 - val_loss: 0.5991 - val_mse: 0.5991
# Epoch 64/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3960 - mse: 0.3960 - val_loss: 0.5941 - val_mse: 0.5941
# Epoch 65/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3886 - mse: 0.3886 - val_loss: 0.5768 - val_mse: 0.5768
# Epoch 66/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3798 - mse: 0.3798 - val_loss: 0.5677 - val_mse: 0.5677
# Epoch 67/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3735 - mse: 0.3735 - val_loss: 0.5563 - val_mse: 0.5563
# Epoch 68/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3642 - mse: 0.3642 - val_loss: 0.5389 - val_mse: 0.5389
# Epoch 69/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3557 - mse: 0.3557 - val_loss: 0.5360 - val_mse: 0.5360
# Epoch 70/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3461 - mse: 0.3461 - val_loss: 0.5169 - val_mse: 0.5169
# Epoch 71/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3374 - mse: 0.3374 - val_loss: 0.5070 - val_mse: 0.5070
# Epoch 72/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3284 - mse: 0.3284 - val_loss: 0.4925 - val_mse: 0.4925
# Epoch 73/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3196 - mse: 0.3196 - val_loss: 0.4761 - val_mse: 0.4761
# Epoch 74/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3117 - mse: 0.3117 - val_loss: 0.4645 - val_mse: 0.4645
# Epoch 75/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3036 - mse: 0.3036 - val_loss: 0.4580 - val_mse: 0.4580
# Epoch 76/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2928 - mse: 0.2928 - val_loss: 0.4330 - val_mse: 0.4330
# Epoch 77/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2839 - mse: 0.2839 - val_loss: 0.4212 - val_mse: 0.4212
# Epoch 78/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2736 - mse: 0.2736 - val_loss: 0.4158 - val_mse: 0.4158
# Epoch 79/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2653 - mse: 0.2653 - val_loss: 0.3981 - val_mse: 0.3981
# Epoch 80/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2557 - mse: 0.2557 - val_loss: 0.3796 - val_mse: 0.3796
# Epoch 81/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2469 - mse: 0.2469 - val_loss: 0.3681 - val_mse: 0.3681
# Epoch 82/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2422 - mse: 0.2422 - val_loss: 0.3609 - val_mse: 0.3609
# Epoch 83/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.3347 - val_mse: 0.3347
# Epoch 84/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2216 - mse: 0.2216 - val_loss: 0.3330 - val_mse: 0.3330
# Epoch 85/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2138 - mse: 0.2138 - val_loss: 0.3171 - val_mse: 0.3171
# Epoch 86/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2041 - mse: 0.2041 - val_loss: 0.3040 - val_mse: 0.3040
# Epoch 87/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1954 - mse: 0.1954 - val_loss: 0.2882 - val_mse: 0.2882
# Epoch 88/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1885 - mse: 0.1885 - val_loss: 0.2770 - val_mse: 0.2770
# Epoch 89/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1784 - mse: 0.1784 - val_loss: 0.2599 - val_mse: 0.2599
# Epoch 90/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1719 - mse: 0.1719 - val_loss: 0.2544 - val_mse: 0.2544
# Epoch 91/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1613 - mse: 0.1613 - val_loss: 0.2300 - val_mse: 0.2300
# Epoch 92/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1531 - mse: 0.1531 - val_loss: 0.2214 - val_mse: 0.2214
# Epoch 93/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1448 - mse: 0.1448 - val_loss: 0.2052 - val_mse: 0.2052
# Epoch 94/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1373 - mse: 0.1373 - val_loss: 0.1951 - val_mse: 0.1951
# Epoch 95/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1298 - mse: 0.1298 - val_loss: 0.1813 - val_mse: 0.1813
# Epoch 96/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1242 - mse: 0.1242 - val_loss: 0.1735 - val_mse: 0.1735
# Epoch 97/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1190 - mse: 0.1190 - val_loss: 0.1625 - val_mse: 0.1625
# Epoch 98/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1107 - mse: 0.1107 - val_loss: 0.1575 - val_mse: 0.1575
# Epoch 99/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1041 - mse: 0.1041 - val_loss: 0.1402 - val_mse: 0.1402
# Epoch 100/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0998 - mse: 0.0998 - val_loss: 0.1339 - val_mse: 0.1339
# Epoch 101/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0943 - mse: 0.0943 - val_loss: 0.1283 - val_mse: 0.1283
# Epoch 102/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0926 - mse: 0.0926 - val_loss: 0.1125 - val_mse: 0.1125
# Epoch 103/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0877 - mse: 0.0877 - val_loss: 0.1149 - val_mse: 0.1149
# Epoch 104/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0814 - mse: 0.0814 - val_loss: 0.1027 - val_mse: 0.1027
# Epoch 105/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0790 - mse: 0.0790 - val_loss: 0.1101 - val_mse: 0.1101
# Epoch 106/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0763 - mse: 0.0763 - val_loss: 0.0964 - val_mse: 0.0964
# Epoch 107/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0705 - mse: 0.0705 - val_loss: 0.0929 - val_mse: 0.0929
# Epoch 108/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0672 - mse: 0.0672 - val_loss: 0.0863 - val_mse: 0.0863
# Epoch 109/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0872 - val_mse: 0.0872
# Epoch 110/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0619 - mse: 0.0619 - val_loss: 0.0816 - val_mse: 0.0816
# Epoch 111/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0761 - val_mse: 0.0761
# Epoch 112/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0584 - mse: 0.0584 - val_loss: 0.0747 - val_mse: 0.0747
# Epoch 113/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0555 - mse: 0.0555 - val_loss: 0.0688 - val_mse: 0.0688
# Epoch 114/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0529 - mse: 0.0529 - val_loss: 0.0676 - val_mse: 0.0676
# Epoch 115/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0507 - mse: 0.0507 - val_loss: 0.0662 - val_mse: 0.0662
# Epoch 116/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0621 - val_mse: 0.0621
# Epoch 117/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0476 - mse: 0.0476 - val_loss: 0.0566 - val_mse: 0.0566
# Epoch 118/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0462 - mse: 0.0462 - val_loss: 0.0628 - val_mse: 0.0628
# Epoch 119/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0447 - mse: 0.0447 - val_loss: 0.0528 - val_mse: 0.0528
# Epoch 120/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0450 - mse: 0.0450 - val_loss: 0.0569 - val_mse: 0.0569
# Epoch 121/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0425 - mse: 0.0425 - val_loss: 0.0509 - val_mse: 0.0509
# Epoch 122/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0555 - val_mse: 0.0555
# Epoch 123/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0392 - mse: 0.0392 - val_loss: 0.0484 - val_mse: 0.0484
# Epoch 124/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0386 - mse: 0.0386 - val_loss: 0.0451 - val_mse: 0.0451
# Epoch 125/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0377 - mse: 0.0377 - val_loss: 0.0475 - val_mse: 0.0475
# Epoch 126/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0365 - mse: 0.0365 - val_loss: 0.0479 - val_mse: 0.0479
# Epoch 127/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0350 - mse: 0.0350 - val_loss: 0.0425 - val_mse: 0.0425
# Epoch 128/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0345 - mse: 0.0345 - val_loss: 0.0429 - val_mse: 0.0429
# Epoch 129/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0335 - mse: 0.0335 - val_loss: 0.0406 - val_mse: 0.0406
# Epoch 130/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0330 - mse: 0.0330 - val_loss: 0.0402 - val_mse: 0.0402
# Epoch 131/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0323 - mse: 0.0323 - val_loss: 0.0392 - val_mse: 0.0392
# Epoch 132/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0310 - mse: 0.0310 - val_loss: 0.0400 - val_mse: 0.0400
# Epoch 133/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0304 - mse: 0.0304 - val_loss: 0.0363 - val_mse: 0.0363
# Epoch 134/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0379 - val_mse: 0.0379
# Epoch 135/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0292 - mse: 0.0292 - val_loss: 0.0352 - val_mse: 0.0352
# Epoch 136/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0287 - mse: 0.0287 - val_loss: 0.0354 - val_mse: 0.0354
# Epoch 137/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0282 - mse: 0.0282 - val_loss: 0.0347 - val_mse: 0.0347
# Epoch 138/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0279 - mse: 0.0279 - val_loss: 0.0337 - val_mse: 0.0337
# Epoch 139/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.0334 - val_mse: 0.0334
# Epoch 140/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0281 - mse: 0.0281 - val_loss: 0.0330 - val_mse: 0.0330
# Epoch 141/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0266 - mse: 0.0266 - val_loss: 0.0343 - val_mse: 0.0343
# Epoch 142/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0259 - mse: 0.0259 - val_loss: 0.0316 - val_mse: 0.0316
# Epoch 143/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0255 - mse: 0.0255 - val_loss: 0.0315 - val_mse: 0.0315
# Epoch 144/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0252 - mse: 0.0252 - val_loss: 0.0322 - val_mse: 0.0322
# Epoch 145/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0249 - mse: 0.0249 - val_loss: 0.0298 - val_mse: 0.0298
# Epoch 146/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0251 - mse: 0.0251 - val_loss: 0.0328 - val_mse: 0.0328
# Epoch 147/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0240 - mse: 0.0240 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 148/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0280 - val_mse: 0.0280
# Epoch 149/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0304 - val_mse: 0.0304
# Epoch 150/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0229 - mse: 0.0229 - val_loss: 0.0278 - val_mse: 0.0278
# Epoch 151/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0278 - val_mse: 0.0278
# Epoch 152/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0226 - mse: 0.0226 - val_loss: 0.0261 - val_mse: 0.0261
# Epoch 153/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0224 - mse: 0.0224 - val_loss: 0.0338 - val_mse: 0.0338
# Epoch 154/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0265 - val_mse: 0.0265
# Epoch 155/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0262 - val_mse: 0.0262
# Epoch 156/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0291 - val_mse: 0.0291
# Epoch 157/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0229 - mse: 0.0229 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 158/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0256 - val_mse: 0.0256
# Epoch 159/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0252 - val_mse: 0.0252
# Epoch 160/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0254 - val_mse: 0.0254
# Epoch 161/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0255 - val_mse: 0.0255
# Epoch 162/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0256 - val_mse: 0.0256
# Epoch 163/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 164/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0236 - val_mse: 0.0236
# Epoch 165/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0292 - val_mse: 0.0292
# Epoch 166/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 167/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0231 - val_mse: 0.0231
# Epoch 168/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0292 - val_mse: 0.0292
# Epoch 169/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0228 - val_mse: 0.0228
# Epoch 170/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0236 - val_mse: 0.0236
# Epoch 171/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0228 - val_mse: 0.0228
# Epoch 172/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0225 - val_mse: 0.0225
# Epoch 173/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0228 - val_mse: 0.0228
# Epoch 174/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0220 - val_mse: 0.0220
# Epoch 175/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 176/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0225 - val_mse: 0.0225
# Epoch 177/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 178/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0228 - val_mse: 0.0228
# Epoch 179/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 180/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0219 - val_mse: 0.0219
# Epoch 181/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 182/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0209 - val_mse: 0.0209
# Epoch 183/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 184/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 185/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 186/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 187/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 188/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0201 - val_mse: 0.0201
# Epoch 189/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0203 - val_mse: 0.0203
# Epoch 190/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0201 - val_mse: 0.0201
# Epoch 191/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 192/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0199 - val_mse: 0.0199
# Epoch 193/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0197 - val_mse: 0.0197
# Epoch 194/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 195/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 196/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 197/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 198/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 199/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0199 - val_mse: 0.0199
# Epoch 200/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 201/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 202/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 203/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 204/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 205/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 206/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 207/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 208/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 209/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 210/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 211/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 212/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 213/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 214/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 215/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 216/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 217/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 218/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 219/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 220/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 221/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 222/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 223/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 224/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 225/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 226/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 227/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 228/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 229/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 230/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 231/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 232/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0165 - val_mse: 0.0165
# Epoch 233/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 234/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 235/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 236/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 237/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 238/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 239/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 240/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 241/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 242/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 243/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 244/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 245/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0165 - val_mse: 0.0165
# Epoch 246/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 247/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 248/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 249/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 250/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 251/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 252/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 253/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 254/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 255/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 256/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 257/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 258/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0165 - val_mse: 0.0165
# Epoch 259/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 260/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 261/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 262/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 263/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 264/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 265/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 266/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 267/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 268/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 269/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 270/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 271/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 272/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 273/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 274/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 275/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 276/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 277/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 278/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 279/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 280/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 281/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 282/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 283/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 284/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 285/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 286/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 287/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 288/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 289/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 290/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 291/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 292/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 293/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 294/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 295/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 296/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 297/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 298/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 299/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 300/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 301/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 302/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 303/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 304/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 305/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 306/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 307/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 308/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 309/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 310/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 311/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 312/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 313/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 314/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 315/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 316/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 317/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 318/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 319/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 320/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 321/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 322/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 323/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 324/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 325/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 326/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 327/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 328/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 329/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 330/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 331/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 332/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 333/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 334/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 335/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 336/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 337/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 338/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 339/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 340/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 341/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 342/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 343/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 344/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 345/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 346/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 347/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 348/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 349/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 350/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 351/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 352/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 353/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 354/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 355/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 356/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 357/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 358/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 359/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 360/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 361/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 362/500
# ...
# Epoch 381/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 382/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 383/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 384/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 385/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 386/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 387/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 388/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 389/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 390/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 391/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 392/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 393/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 394/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 395/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 396/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 397/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 398/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 399/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 400/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 401/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 402/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 403/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 404/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 405/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 406/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 407/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 408/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 409/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 410/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 411/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 412/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 413/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 414/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 415/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 416/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 417/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 418/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 419/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 420/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 421/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 422/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 423/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 424/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 425/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 426/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 427/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 428/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 429/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 430/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 431/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 432/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 433/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 434/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 435/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 436/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 437/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 438/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 439/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 440/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 441/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 442/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 443/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 444/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 445/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 446/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 447/500
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 448/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 449/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 450/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 451/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 452/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 453/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 454/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 455/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 456/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 457/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 458/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 459/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 460/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 461/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 462/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 463/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 464/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 465/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 466/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 467/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 468/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 469/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 470/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 471/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 472/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 473/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 474/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 475/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 476/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 477/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 478/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 479/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 480/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 481/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 482/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 483/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 484/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 485/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 486/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 487/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 488/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 489/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 490/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 491/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 492/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 493/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 494/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 495/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 496/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 497/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 498/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 499/500
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 500/500
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0115 - val_mse: 0.0115

# %% [markdown]
# Valuto il modello allenato applicandolo al validation set

# %%
# evaluate model
score_val_data = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)
score_target_data = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)
val_loss, val_accuracy = score_val_data
target_loss, target_accuracy = score_target_data
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0115 - mse: 0.0115
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0014 - mse: 0.0014

# %%
print('Test loss on validation data:', val_loss)
print('Test loss on target data:', target_loss)
# Out:
# Test loss on validation data: 0.011540748178958893
# Test loss on target data: 0.0014427447458729148

# %% [markdown]
# Mostro l'andamento della loss valutata sul test set e sul training set in funzione dell'epoca

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %% [markdown]
# Mostro le predizioni del modello sui dati target

# %%
x_predicted = np.random.uniform(-2, 2, 200)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r', label='predicted')
plt.plot(x_valid, y_target, label='target')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# Salvo i risultati su file

# %%
#create directory for saving output
ndir = f"{para['simulation_name']}_outfiles"

try:
    os.mkdir(ndir)
except FileExistsError:
    pass

#saving parameters
with open(f"{ndir}/para.js", 'w') as para_f:
    json.dump(para, para_f)
    
#saving test set and validation set
data = {'x_train': x_train.tolist(), 'y_train': y_train.tolist(), 
       'x_valid': x_valid.tolist(), 'y_valid': y_valid.tolist()}
with open(f"{ndir}/data.js", 'w') as data_f:
    json.dump(data, data_f)

#saving history
with open(f"{ndir}/history.js", 'w') as history_f:
    json.dump(history.history, history_f)

#saving scores
scores = {'val_loss': val_loss, 'target_loss': target_loss}
with open(f"{ndir}/scores.js", 'w') as scores_f:
    json.dump(scores, scores_f)
    
#saving x_predicted and y_predicted
predicted = {'x_predicted': x_predicted.tolist(), 'y_predicted': y_predicted.tolist()}
with open(f"{ndir}/predicted.js", 'w') as pred_f:
    json.dump(predicted, pred_f)

# %% [markdown]
# ## 4 Esercizio 1

# %% [markdown]
# In questo esercizio viene studiato l'utilizzo della rete per la regressione di alcuni dati estratti utilizzando come funzione target
#
# $$
#     f(x) = 2x +1
# $$
#
# Essendo una funzione lineare dovrebbe bastare un solo neurone, senza funzione di attivazione, per eseguire la regressione.
# Ho quindi utilizzato il codice precedente mantenendo fissati i seguenti parametri:
# - 0 hidden layer
# - nessuna funzione di attivazione
# - ottimizzatore: 'adam'
# - loss function: scarto quadratico medio, ovvero
#
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
#
# Ho variato, nel corso delle diverse simulazioni che ho eseguito
# - la dimensione del training set
# - la `sigma` che rappresenta la deviazione standard della distribuzione gaussiana con cui viene generato il rumore aggiunto ai dati. Valori maggiori corrispondono a dati più rumorosi.
#
# Dallo storico della loss function valutata nel corso delle diverse epoche, ho anche valutato l'influenza del valore di questo parametro (numero di epoche) sui risultati che si possono ottenere.

# %% [markdown]
# ### 4.1 Variazione del parametro sigma

# %% [markdown]
# Ho eseguito diverse simulazioni variando il parametro $\sigma$. In questo modo vengono generati dati di training e validazione caratterizzati da diversa rumorosità. Sotto sono presentati i risultati che ho ottenuto con alcuni valori specifici di $\sigma$. In tutti i casi il training set generato è costituito da 500 punti.

# %%
n_tests = 4
fig, axes = plt.subplots(2,2)
axes = axes.flatten()
fig.set_size_inches(12,10)

para = []
for i in range(0, n_tests):
        cdir = f"es1test{i+1}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/para.js") as para_f:
            para.append(json.load(para_f))
        
        #getting training sets
        with open(f"{cdir}/data.js") as data_f:
            data = json.load(data_f)
        
        #getting predictedd values
        with open(f"{cdir}/predicted.js") as pred_f:
            pred = json.load(pred_f)
            
        axes[i].set_title(f"dati di training generati con $\sigma$ = {para[-1]['sigma']}")
    
        axes[i].scatter(data['x_train'], data['y_train'], marker='.')
        axes[i].plot(pred['x_predicted'], pred['y_predicted'], color='orange')
        x_target = target_function_es1(np.array((pred['x_predicted'])))
        axes[i].plot(pred['x_predicted'],x_target, color='red')
        axes[i].set_ylabel('y')
        axes[i].set_xlabel('x')
        axes[i].legend([ 'Preditted curve', 'Target curve', 'Train set'], loc='best')
        
plt.tight_layout()
plt.show()

# %% [markdown]
# In questi primi grafici, ciascuno relativo alla regressione di dati differenti, è possibile osservare i punti del training set corrispondente, la curva della funzione target e la curva ottenuta dall'allenamento del modello. Come aspettato l'accuratezza del modello, rispetto alla funzione target, diminuisce all'aumentare della rumorosità dei dati. Tuttavia anche nel caso dell'ultimo set molto rumoroso il modello ottenuto sembra riprodurre abbastanza bene la funzione target.
#
# Queste affermazioni qualitative sono supportate quantitativamente valutando il modello con la funzione di costo. Ho valutato lo scarto quadratico medio dei punti predetti dal modello sia per il validation set, costituito da punti a cui è stato applicato il rumore, sia su un nuovo set di punti privo di rumore.

# %%
print('Calcolo dello scarto quadratico medio\n')
for i in range(0, n_tests):
        cdir = f"es1test{i+1}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/scores.js") as scores_f:
            scores = json.load(scores_f)
        
        print(f"Regressione dei dati generati con σ = {para[i]['sigma']:.1f}\n")
        print(f"\t mse calcolato sul validation set\t\t\t: {scores['val_loss']:.4f}")
        print(f"\t mse calcolato su un set di punti target senza rumore\t: {scores['target_loss']:.4f}\n")
# Out:
# Calcolo dello scarto quadratico medio
#
# Regressione dei dati generati con σ = 0.1
#
# 	 mse calcolato sul validation set			: 0.0106
# 	 mse calcolato su un set di punti target senza rumore	: 0.0002
#
# Regressione dei dati generati con σ = 0.3
#
# 	 mse calcolato sul validation set			: 0.1001
# 	 mse calcolato su un set di punti target senza rumore	: 0.0014
#
# Regressione dei dati generati con σ = 0.5
#
# 	 mse calcolato sul validation set			: 0.2807
# 	 mse calcolato su un set di punti target senza rumore	: 0.0045
#
# Regressione dei dati generati con σ = 1.0
#
# 	 mse calcolato sul validation set			: 1.1160
# 	 mse calcolato su un set di punti target senza rumore	: 0.0163

# %% [markdown]
# Come si può vedere l'mse aumenta in entrambi i casi all'aumentare del rumore dei dati. Tuttavia mentre il valore calcolato sui dati rumorosi cresce significativamente divenendo maggiore della stessa $\sigma$, l'errore rispetto alla funzione target rimane contenuto.
#
# È poi interessante studiare l'evoluzione del valore della loss function durante l'evoluzione. Queste informazioni sono contenute nei grafici successivi.

# %%
fig, axes = plt.subplots(2,2)
axes = axes.flatten()
fig.set_size_inches(12,7)

for i in range(0, n_tests):
        cdir = f"es1test{i+1}_outfiles"
        
        #getting history of loss
        with open(f"{cdir}/history.js") as history_f:
            hist = json.load(history_f)
            
        axes[i].set_title(f"Regressione dei dati generati con $\sigma$ = {para[i]['sigma']}")
        
        axes[i].plot(hist['loss'])
        axes[i].plot(hist['val_loss'])
        axes[i].set_ylabel('Loss')
        axes[i].set_xlabel('Epoch')
        axes[i].set_xscale('log')
        axes[i].legend(['Train', 'Test'], loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Come si può vedere nei grafici è rappresentato il valore della loss in funzione dell'epoca valutata sia sul training set che sul set di validazione. Come prima osservazione si noti che in tutti i casi viene raggiunto il valore minimo dopo qualche centinaio circa di epoche. La simulazione di 500 o 300 epoche è quindi sufficiente.
#
# Noto, diversamente da come mi sarei aspettato, che le curve relative al training set meno rumoroso raggiungono il minimo in un numero superiore di epoche rispetto a quelle degli altri set di dati. Tuttavia, una volta raggiunto il minimo questo è inferiore rispetto al valore ottenuto negli altri casi. Inoltre, i dati più rumorosi determinano delle differenze tra i valori della loss function valutata sul training set e quelli della stessa funzione valutata sul set di validazione.

# %% [markdown]
# ### 4.2 Variazione della dimensione del training set

# %% [markdown]
# La dimensione del training set è uno dei parametri più importanti in tutte le applicazioni di tecniche di machine learning.
#
# Ho studiato come questo parametro influenza la capacità predittiva del modello eseguendo 3 regressioni a partire da 3 training set di diverse dimensioni. Ho eseguito poi analoghe regressioni mantenendo tutti i parametri invariati ma aumentando la rumorosità (e quindi $\sigma$) dei dati.

# %%
n_tests = 6
fig, axes = plt.subplots(2,3)
axes = axes.flatten()
fig.set_size_inches(15,8)

para = []
for i in range(0, n_tests):
        cdir = f"es1test{i+5}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/para.js") as para_f:
            para.append(json.load(para_f))
        
        #getting training sets
        with open(f"{cdir}/data.js") as data_f:
            data = json.load(data_f)
        
        #getting predictedd values
        with open(f"{cdir}/predicted.js") as pred_f:
            pred = json.load(pred_f)
            
        axes[i].set_title(f"{para[-1]['n_train_data']} punti di training generati con $\sigma$ = {para[-1]['sigma']}")
    
        axes[i].scatter(data['x_train'], data['y_train'], marker='.')
        axes[i].plot(pred['x_predicted'], pred['y_predicted'], color='orange')
        x_target = target_function_es1(np.array((pred['x_predicted'])))
        axes[i].plot(pred['x_predicted'],x_target, color='red')
        axes[i].set_ylabel('y')
        axes[i].set_xlabel('x')
        axes[i].legend([ 'Preditted curve', 'Target curve', 'Train set'], loc='best')

plt.tight_layout()
plt.show()

print('Calcolo dello scarto quadratico medio\n')
for i in range(0, n_tests):
        cdir = f"es1test{i+5}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/scores.js") as scores_f:
            scores = json.load(scores_f)
        
        print(f"Regressione dei {para[i]['n_train_data']} dati generati con σ = {para[i]['sigma']:.1f}\n")
        print(f"\t mse calcolato sul validation set\t\t\t: {scores['val_loss']:.4f}")
        print(f"\t mse calcolato su un set di punti target senza rumore\t: {scores['target_loss']:.2}\n")
# Out:
# Calcolo dello scarto quadratico medio
#
# Regressione dei 10 dati generati con σ = 0.1
#
# 	 mse calcolato sul validation set			: 0.8101
# 	 mse calcolato su un set di punti target senza rumore	: 0.73
#
# Regressione dei 50 dati generati con σ = 0.1
#
# 	 mse calcolato sul validation set			: 0.0105
# 	 mse calcolato su un set di punti target senza rumore	: 0.0016
#
# Regressione dei 100 dati generati con σ = 0.1
#
# 	 mse calcolato sul validation set			: 0.0076
# 	 mse calcolato su un set di punti target senza rumore	: 1.4e-06
#
# Regressione dei 10 dati generati con σ = 0.5
#
# 	 mse calcolato sul validation set			: 0.3684
# 	 mse calcolato su un set di punti target senza rumore	: 0.046
#
# Regressione dei 50 dati generati con σ = 0.5
#
# 	 mse calcolato sul validation set			: 1.5611
# 	 mse calcolato su un set di punti target senza rumore	: 1.4
#
# Regressione dei 100 dati generati con σ = 0.5
#
# 	 mse calcolato sul validation set			: 0.1929
# 	 mse calcolato su un set di punti target senza rumore	: 2.6e-05

# %% [markdown]
# In questi grafici si può innanzitutto osservare come la rumorosità dei dati sia strettamente correlata alla dimensione del set di training necessaria ad ottenere modelli sufficientemente accurati. Si nota infatti che nel caso di dati poco rumorosi sono sufficienti 50 punti per avere dei buoni risultati mentre aumentando il rumore tale numero non è più sufficiente.
# Ovviamente in entrambi i casi l'accuratezza del modello migliora al crescere della dimensione del set di allenamento.

# %%
fig, axes = plt.subplots(2,3)
axes = axes.flatten()
fig.set_size_inches(12,7)

for i in range(0, n_tests):
        cdir = f"es1test{i+5}_outfiles"
        
        #getting history of loss
        with open(f"{cdir}/history.js") as history_f:
            hist = json.load(history_f)
            
        axes[i].set_title(f"Regressione dei {para[i]['n_train_data']} dati generati con $\sigma$ = {para[i]['sigma']}")
        
        axes[i].plot(hist['loss'])
        axes[i].plot(hist['val_loss'])
        axes[i].set_ylabel('Loss')
        axes[i].set_xlabel('Epoch')
        axes[i].set_xscale('log')
        axes[i].legend(['Train', 'Test'], loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Anche questi grafici rispecchiano gli stessi concetti. In aggiunta si può osservare che nelle due regressioni effettuate con training set costituiti da 10 punti entrambe le curve decrescono fino all'ultima epoca. Questo indica la possibilità di ottenere risultati migliori aumentandone il numero.
# La stessa osservazione non può essere fatta nelle regressioni effettuate con 50 punti poichè in questo caso, sebbene la loss function valutata sul training set continui a diminuire, la loss valutata sul test set raggiunge un valore di saturazione.

# %% [markdown]
# ## 5 Esercizio 2

# %% [markdown]
# In questo secondo esercizio viene utilizzato sempre lo stesso codice dell'esercizio precedente sostituendo però la nuova funzione target
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
#
# Anche in questo caso l'obiettivo è la regressione di alcuni punti generati da questa funzione con l'aggiunta di rumore gaussiano. Le $x$ contenute nei training e test set saranno comprese tra -1 e 1.
#
# In questo esercizio viene studiato l'effetto della variazione dei seguenti iperparametri:
# - numero di layer
# - numero di neuroni in ciascun layer
# - funzione di attivazione
# - ottimizzatore
# - loss function
#
# Quando non diversamente specificato, gli altri parametri assumono i seguenti valori:
# - sigma pari 0.1
# - 500 punti nel training set
# - 50 punti nel set di validazione
# - 500 epoche

# %% [markdown]
# ### 5.2 Variazione del numero di layer nascosti e della loro dimensione

# %% [markdown]
# Come primo esperimento ho variato la struttura della rete modificando il numero di layer nascosti e la loro dimensione.
# Subito sotto sono presenti i risultati ottenuti con alcune di queste strutture. Per esse ho mantenuto invariati l'ottimizzatore (adam), la funzione di attivazione (relu) e la funzione di costo (mse). Anche gli altri parametri sono quelli standard già elencati ad eccezione del parametro sigma che è stato variato tra la prima e seconda coppia di simulazioni.

# %%
n_tests = 4
fig, axes = plt.subplots(2,2)
axes = axes.flatten()
fig.set_size_inches(12,8)

para = []
for i in range(0, n_tests):
        cdir = f"es2test{i+1}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/para.js") as para_f:
            para.append(json.load(para_f))
        
        #getting training sets
        with open(f"{cdir}/data.js") as data_f:
            data = json.load(data_f)
        
        #getting predictedd values
        with open(f"{cdir}/predicted.js") as pred_f:
            pred = json.load(pred_f)
            
        axes[i].set_title(f"{para[-1]['n_hidden_layers']} layer nascosti da " + 
                          f" {para[-1]['n_neurons_per_layer']} neuroni ciascuno (σ = {para[-1]['sigma']})")
    
        axes[i].scatter(data['x_train'], data['y_train'], marker='.')
        axes[i].scatter(pred['x_predicted'], pred['y_predicted'], color='orange')
        x_target = target_function_es2(np.sort((pred['x_predicted'])))
        axes[i].plot(np.sort(pred['x_predicted']),x_target, color='red')
        axes[i].set_ylabel('y')
        axes[i].set_xlabel('x')
        axes[i].legend([ 'Preditted curve', 'Target curve', 'Train set'], loc='best')

plt.tight_layout()
plt.show()

print('Calcolo dello scarto quadratico medio\n')
for i in range(0, n_tests):
        cdir = f"es2test{i+1}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/scores.js") as scores_f:
            scores = json.load(scores_f)
        
        print(f"Regressione dei {para[i]['n_train_data']} dati generati con σ = {para[i]['sigma']:.1f}\n")
        print(f"\t mse calcolato sul validation set\t\t\t: {scores['val_loss']:.4f}")
        print(f"\t mse calcolato su un set di punti target senza rumore\t: {scores['target_loss']:.2}\n")
# Out:
# Calcolo dello scarto quadratico medio
#
# Regressione dei 500 dati generati con σ = 0.1
#
# 	 mse calcolato sul validation set			: 0.0124
# 	 mse calcolato su un set di punti target senza rumore	: 0.0016
#
# Regressione dei 500 dati generati con σ = 0.1
#
# 	 mse calcolato sul validation set			: 0.0122
# 	 mse calcolato su un set di punti target senza rumore	: 0.0013
#
# Regressione dei 500 dati generati con σ = 0.5
#
# 	 mse calcolato sul validation set			: 0.2630
# 	 mse calcolato su un set di punti target senza rumore	: 0.013
#
# Regressione dei 500 dati generati con σ = 0.5
#
# 	 mse calcolato sul validation set			: 0.2676
# 	 mse calcolato su un set di punti target senza rumore	: 0.011

# %% [markdown]
# In entrambi i modelli di rete neurale utilizzati sono presenti 16 neuroni negli strati nascosti. La diversa disposizione fa però si che la rete costituita da un solo layer nascosto disponga di 51 parametri allenabili mentre quella costituita da due layer ne ha 99. Mi aspetterei quindi che quest'ultima performi meglio. Le aspettative vengono soddisfatte solo nella regressione dei dati meno rumorosi. Tuttavia la differenza tra i valori delle loss function è minima, ciò mi porterebbe a concludere che non vi sia una reale differenza tra i due modelli. La funzione che si sta cercando di riprodurre è un polinomio di terzo grado che è quindi completamente definito da 4 parametri. Queste reti potrebbero essere sovradimensionate per il problema che si sta affrontando.

# %% [markdown]
# Gli andamenti delle funzioni di loss, presenti qui sotto, non offrono particolari informazioni aggiuntive. Permettono solamente di concludere che tutta la potenzialità delle varie reti è stata sfruttata appieno in quanto nelle ultime epoche i valori appaiono saturati su minimi costanti. Non mi aspetto che aumentando il numero delle epoche si ottengano risultati significativamente migliori.

# %%
fig, axes = plt.subplots(2,2)
axes = axes.flatten()
fig.set_size_inches(12,7)

for i in range(0, n_tests):
        cdir = f"es2test{i+1}_outfiles"
        
        #getting history of loss
        with open(f"{cdir}/history.js") as history_f:
            hist = json.load(history_f)
            
        axes[i].set_title(f"{para[i]['n_hidden_layers']} layer nascosti da " + 
                          f" {para[i]['n_neurons_per_layer']} neuroni ciascuno")
        
        axes[i].plot(hist['loss'])
        axes[i].plot(hist['val_loss'])
        axes[i].set_ylabel('Loss')
        axes[i].set_xlabel('Epoch')
        axes[i].set_xscale('log')
        axes[i].legend(['Train', 'Test'], loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3 Variazione della funzione di attivazione

# %% [markdown]
# La funzione di attivazione è una funzione $\mathbb{R} \rightarrow \mathbb R$ contenuta all'interno del singolo neurone che ne restituisce l'output in funzione della somma pesata dei valori di input provenienti dalle varie connessioni in ingresso.
#
# Esistono diversi tipi di funzioni di attivazione. Ne ho sperimentate 3:
#
# - la relu (rectified linear unit): f(x) = max(x, 0)
# - la sigmoide: f(x) = 1 / (1 + exp(-x))
# - l'esponenziale: f(x) = exp(x)
#
# La sigmoide è sostanzialmente diversa dalle altre due in quanto limitata anche superiormente.

# %%
n_tests = 3
fig, axes = plt.subplots(3,2)
#axes = axes.flatten()
fig.set_size_inches(12,12)

para = []
for i in range(0, n_tests):
        cdir = f"es2test{i+8}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/para.js") as para_f:
            para.append(json.load(para_f))
        
        #getting training sets
        with open(f"{cdir}/data.js") as data_f:
            data = json.load(data_f)
        
        #getting predictedd values
        with open(f"{cdir}/predicted.js") as pred_f:
            pred = json.load(pred_f)
            
        #getting history of loss
        with open(f"{cdir}/history.js") as history_f:
            hist = json.load(history_f)
            
        axes[i][0].set_title(f"funzione di attivazione: {para[-1]['activation_function']}")
    
        axes[i][0].scatter(data['x_train'], data['y_train'], marker='.')
        axes[i][0].scatter(pred['x_predicted'], pred['y_predicted'], color='orange')
        x_target = target_function_es2(np.sort((pred['x_predicted'])))
        axes[i][0].plot(np.sort(pred['x_predicted']),x_target, color='red')
        axes[i][0].set_ylabel('y')
        axes[i][0].set_xlabel('x')
        axes[i][0].legend([ 'Preditted curve', 'Target curve', 'Train set'], loc='best')
    
        axes[i][1].plot(hist['loss'])
        axes[i][1].plot(hist['val_loss'])
        axes[i][1].set_ylabel('Loss')
        axes[i][1].set_xlabel('Epoch')
        axes[i][1].set_xscale('log')
        axes[i][1].legend(['Train', 'Test'], loc='best')
        
plt.tight_layout()
plt.show()

print('Calcolo dello scarto quadratico medio\n')
for i in range(0, n_tests):
        cdir = f"es2test{i+8}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/scores.js") as scores_f:
            scores = json.load(scores_f)
        
        print(f"funzione di attivazione: {para[-1]['activation_function']}")
        print(f"\t mse calcolato sul validation set\t\t\t: {scores['val_loss']:.4f}")
        print(f"\t mse calcolato su un set di punti target senza rumore\t: {scores['target_loss']:.2}\n")
# Out:
# Calcolo dello scarto quadratico medio
#
# funzione di attivazione: exponential
# 	 mse calcolato sul validation set			: 0.0157
# 	 mse calcolato su un set di punti target senza rumore	: 0.0047
#
# funzione di attivazione: exponential
# 	 mse calcolato sul validation set			: 0.4429
# 	 mse calcolato su un set di punti target senza rumore	: 0.45
#
# funzione di attivazione: exponential
# 	 mse calcolato sul validation set			: 0.0552
# 	 mse calcolato su un set di punti target senza rumore	: 0.036

# %% [markdown]
# Si può osservare la diversità dei risultati ottenuti variando la funzione di attivazione. Tra le tre quella che appare più performante è la 'relu'. Utilizzando le altre funzioni di attivazione si può notare come il risultato della regressione sia abbastanza diverso dalla funzione target. La scelta della funzione di attivazione è quindi da valutare con attenzione nell'implementazione di un modello.

# %% [markdown]
# ### 5.4 Optimizers

# %% [markdown]
# L'ottimizzatore è l'algoritmo che viene utilizzato per ricercare la configurazione di parametri che minimizza la loss function. Ne esistono diversi. Un punto di partenza comune a molti è il concetto di discesa del gradiente. Se si suppone che il vettore $\vec w$ rappresenti i parametri della rete neurale, la funzione di costo può essere pensata come una funzione di questi parametri $L(\vec w)$ e l'allenamento della rete neurale corrisponde alla ricerca del suo minimo. L'algoritmo si basa sul fatto che in un punto $\vec w$ la direzione di massima discesa della funzione $L(\vec w)$ è quella individuata dalla direzione dell'opposto del gradiente. Ciascuno step corrisponde quindi al passaggio dal set di parametri $\vec w_i$ al set di parametri $\vec w_{i+1}$ secondo:
#
# $$
# \vec w_{i+1} = \vec w_i - \eta \vec \nabla { L(\vec w_i)}
# $$
#
# dove $\eta$ è un nuovo iperparametro detto "learning rate" che gestisce la velocità dell'algoritmo permettendo di controllare alcuni effetti indesiderati.
# La funzione di costo, in questo caso lo scarto quadratico medio, viene normalmente calcolata su tutto il set di allenamento. Tuttavia, questa operazione può risultare particolarmente costosa computazionalmente. Per questa ragione una alternativa più comunemente utilizzata è la discesa stocastica del gradiente in cui la funzione di loss viene valutata solamente su un ristretto sottoinsieme del training set scelto casualmeente ad ogni iterazione. Questo ottimizzatore è chiamato in keras `sgd`.
#
# Gli altri ottimizzatori che ho sperimentato sono `adam` e `Adagrad`.
#
# `Adagrad` è un ottimizzatore basato sempre sull'algoritmo della discesa del gradiente caratterizzato da learning rate diversi per ciascuna componente del gradiente. Inoltre, tali valori vengono adattati durante l'allennamento in modo che i parametri che vengono aggiornati più frequentemente abbiano un learning rate minore.
#
# `adam` è basato sull'algoritmo della discesa stocastica del gradiente con l'aggiunta dei momenti al primo e secondo ordine. I momenti sono termini aggiuntivi proporzionali alla velocità con cui variano i parametri e che introducono una sorta di inerzia alla loro variazione. Questo metodo si basa sulla stima adattiva di questi momenti. Dalla documentazione:
# > According to Kingma et al., 2014, the method is "computationally efficient, has little memory requirement, invariant to diagonal rescaling of gradients, and is well suited for problems that are large in terms of data/parameters".
#
# Nei grafici successivi sono presentati i risultati ottenuti con questi 3 ottimizzatori. In tutti i casi vengono utilizzate reti neurali costituite da due layer nascosti da 16 neuroni ciascuno. Come funzione di attivazione viene utilizzata la `relu` e come funzione di costo sempre lo scarto quadratico medio.

# %%
n_tests = 3
fig, axes = plt.subplots(3,2)
#axes = axes.flatten()
fig.set_size_inches(12,12)

para = []
for i in range(0, n_tests):
        cdir = f"es2test{i+11}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/para.js") as para_f:
            para.append(json.load(para_f))
        
        #getting training sets
        with open(f"{cdir}/data.js") as data_f:
            data = json.load(data_f)
        
        #getting predictedd values
        with open(f"{cdir}/predicted.js") as pred_f:
            pred = json.load(pred_f)
            
        #getting history of loss
        with open(f"{cdir}/history.js") as history_f:
            hist = json.load(history_f)
            
        axes[i][0].set_title(f"ottimizzatore: {para[-1]['opt']}")
    
        axes[i][0].scatter(data['x_train'], data['y_train'], marker='.')
        axes[i][0].scatter(pred['x_predicted'], pred['y_predicted'], color='orange')
        x_target = target_function_es2(np.sort((pred['x_predicted'])))
        axes[i][0].plot(np.sort(pred['x_predicted']),x_target, color='red')
        axes[i][0].set_ylabel('y')
        axes[i][0].set_xlabel('x')
        axes[i][0].legend([ 'Preditted curve', 'Target curve', 'Train set'], loc='best')
    
        axes[i][1].plot(hist['loss'])
        axes[i][1].plot(hist['val_loss'])
        axes[i][1].set_ylabel('Loss')
        axes[i][1].set_xlabel('Epoch')
        axes[i][1].set_xscale('log')
        axes[i][1].legend(['Train', 'Test'], loc='best')
        
plt.tight_layout()
plt.show()

print('Calcolo dello scarto quadratico medio\n')
for i in range(0, n_tests):
        cdir = f"es2test{i+11}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/scores.js") as scores_f:
            scores = json.load(scores_f)
        
        print(f"ottimizztore: {para[i]['opt']}")
        print(f"\t mse calcolato sul validation set\t\t\t: {scores['val_loss']:.4f}")
        print(f"\t mse calcolato su un set di punti target senza rumore\t: {scores['target_loss']:.2}\n")
# Out:
# Calcolo dello scarto quadratico medio
#
# ottimizztore: adam
# 	 mse calcolato sul validation set			: 0.0131
# 	 mse calcolato su un set di punti target senza rumore	: 0.0021
#
# ottimizztore: sgd
# 	 mse calcolato sul validation set			: 0.0113
# 	 mse calcolato su un set di punti target senza rumore	: 0.0027
#
# ottimizztore: Adagrad
# 	 mse calcolato sul validation set			: 2.7505
# 	 mse calcolato su un set di punti target senza rumore	: 2.7

# %% [markdown]
# Si può osservare come entrambi gli ottimizzatori `sgd` e `adam` abbiano dato dei buoni risultati permettendo di  raggiungere il minimo entro qualche centinaio di epoche.
#
# L'ottimizzatore `Adagrad` sembra invece fallire. La loss function valutata sui set  di allenamento e validazione decresce fino all'ultima epoca, questo potrebbe indicare che aumentando il numero di epoche potrebbe essere possibile ottenere un minimo anche con questo ottimizzatore.
#
# Anche questo parametro deve quindi essere valutato con attenzione quando si implementa un modello di rete neurale.

# %% [markdown]
# ### 5.5 Loss

# %% [markdown]
# Un altro parametro che può essere esplorato è la funzione di costo. Ho eseguito alcune regressioni utilizzando i seguenti parametri fissi:
# - 2 layer nascosti
# - 16 neuroni per ogni layer nascosto
# - ottimizzatore: `adam`
# - funzione di attivazione: `relu`
#
# Ho sperimentato diverse funzioni di costo, tra queste riporto i risultati ottenuti con le seguenti:
#
# - __mean_squared_error__ $= \frac{1}{N} \sum_{i=1}^N \left| y_i^{out}-y_i^{lab}\right|^2$
#
# - __mean_absolute_error__ $= \frac{1}{N} \sum_{i=1}^N \left| y_i^{out}-y_i^{lab}\right|$
#     Differisce dalla precedente per il quadrato. Questo rende il MSE più sensibile, rispetto al MAE, agli errori più grandi che quindi verranno penalizzati maggiormente.
#
# - __mean_squared_logarithmic_error__ $=\frac{1}{N}\sum_{i=1}^N \left|\log\frac{y_i^{out}+1}{y_i^{lab}+1}\right|^2$
#     Questa funzione di costo viene solitamente utilizzata quando non si vogliono penalizzare eccessivamente grandi errori presenti soprattutto se la funzione da predire assume valori grandi.

# %%
n_tests = 3
fig, axes = plt.subplots(3,2)
#axes = axes.flatten()
fig.set_size_inches(12,12)

para = []
for i in range(0, n_tests):
        cdir = f"es2test{i+14}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/para.js") as para_f:
            para.append(json.load(para_f))
        
        #getting training sets
        with open(f"{cdir}/data.js") as data_f:
            data = json.load(data_f)
        
        #getting predictedd values
        with open(f"{cdir}/predicted.js") as pred_f:
            pred = json.load(pred_f)
            
        #getting history of loss
        with open(f"{cdir}/history.js") as history_f:
            hist = json.load(history_f)
            
        axes[i][0].set_title(f"funzione di costo: {para[-1]['loss_function']}")
    
        axes[i][0].scatter(data['x_train'], data['y_train'], marker='.')
        axes[i][0].scatter(pred['x_predicted'], pred['y_predicted'], color='orange')
        x_target = target_function_es2(np.sort((pred['x_predicted'])))
        axes[i][0].plot(np.sort(pred['x_predicted']),x_target, color='red')
        axes[i][0].set_ylabel('y')
        axes[i][0].set_xlabel('x')
        axes[i][0].legend([ 'Preditted curve', 'Target curve', 'Train set'], loc='best')
    
        axes[i][1].plot(hist['loss'])
        axes[i][1].plot(hist['val_loss'])
        axes[i][1].set_ylabel('Loss')
        axes[i][1].set_xlabel('Epoch')
        axes[i][1].set_xscale('log')
        axes[i][1].legend(['Train', 'Test'], loc='best')
        
plt.tight_layout()
plt.show()

print('Calcolo dello scarto quadratico medio\n')
for i in range(0, n_tests):
        cdir = f"es2test{i+14}_outfiles"
        
        #getting parameters
        with open(f"{cdir}/scores.js") as scores_f:
            scores = json.load(scores_f)
        
        print(f"funzione di costo: {para[i]['loss_function']}")
        print(f"\t mse calcolato sul validation set\t\t\t: {scores['val_loss']:.4f}")
        print(f"\t mse calcolato su un set di punti target senza rumore\t: {scores['target_loss']:.2}\n")
# Out:
# Calcolo dello scarto quadratico medio
#
# funzione di costo: mse
# 	 mse calcolato sul validation set			: 0.0127
# 	 mse calcolato su un set di punti target senza rumore	: 0.0014
#
# funzione di costo: mae
# 	 mse calcolato sul validation set			: 0.0901
# 	 mse calcolato su un set di punti target senza rumore	: 0.04
#
# funzione di costo: msle
# 	 mse calcolato sul validation set			: 0.0009
# 	 mse calcolato su un set di punti target senza rumore	: 0.00013

# %% [markdown]
# Come si può osservare tutte le diverse funzioni di costo permettono una buona regressione dei dati. Le differenze si notano principalmente nell'evoluzione del valore della funzione di costo nel corso delle varie epoche. Tra le 3 quella che risulta più performante è la `msle`.
#
# La scelta della funzione di costo risulta anche legata agli altri parametri. Ho eseguito numerosi altri test in cui ho verificato alcune di queste complicate relazioni. Ad esempio si può osservare una certa dipendenza con la scelta della funzione di attivazione.

# %% [markdown]
# ### 5.6 Predizioni fuori dal range dei dati
# Infine un'osservazione che vale la pena compiere è relativa alla capacità predittiva del modello fuori dall'intervallo di valori in cui è stato allenato.

# %%
fig, axe = plt.subplots(1)
axes = axes.flatten()
fig.set_size_inches(8,6)

cdir = "es2test17_outfiles"

#getting parameters
with open(f"{cdir}/para.js") as para_f:
    para = json.load(para_f)

#getting training sets
with open(f"{cdir}/data.js") as data_f:
    data = json.load(data_f)

#getting predictedd values
with open(f"{cdir}/predicted.js") as pred_f:
    pred = json.load(pred_f)
            
axe.set_title("Valutazione della curva ottenuta fuori dall'intervallo di allenamento")

axe.scatter(data['x_train'], data['y_train'], marker='.')
axe.scatter(pred['x_predicted'], pred['y_predicted'], color='orange')
x_target = target_function_es2(np.sort((pred['x_predicted'])))
axe.plot(np.sort(pred['x_predicted']),x_target, color='red')
axe.set_ylabel('y')
axe.set_xlabel('x')
axe.legend([ 'Target curve', 'Train set','Preditted curve'], loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Come si può chiaramente osservare la curva ottenuta dal modello fallisce in maniera evidente nel predire la curva target fuori dall'intervallo in cui è stato allenato. Questo è uno dei limiti dello strumento delle reti neurali.

# %% [markdown]
# # Esercizio 3

# %% [raw]
# L'obettivo di questo terzo esercizio è l'implementazione di un modello di rete neurale analogo ai precedenti ma realizzato per la regressione di una superficie in 3 dimensioni.
#
# La curva target è la seguente:
# $$
# f(x,y) = \sin(x^2+y^2)
# $$
#
# In seguito è riportato il codice che ho utilizzato per generare i dati e per definire ed eseguire il modello. Con questo codice ho sperimentato come in precedenza diverse configurazioni degli iperparametri. I grafici riportati sono relativi alla configurazione con cui ho ottenuto i risultati migliori.

# %%
#iperparametri

n_hidden_layers = 1
n_neurons_per_layer = 128
activation_function = 'relu'
opt = 'adam'
loss_function = 'mse'

sigma = 0.3
n_epochs = 300
n_train_data = 5000
n_valid_data = 5000

#genero i dati
def target_function(x, y):
    return np.sin(x**2+y**2)

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-3/2, 3/2, n_train_data)
x_valid = np.random.uniform(-3/2, 3/2, n_valid_data)
y_train = np.random.uniform(-3/2, 3/2, n_train_data)
y_valid = np.random.uniform(-3/2, 3/2, n_valid_data)
z_target = target_function(x_valid, y_valid) # ideal (target) linear function

# noise standard deviation, for the moment it is absent
z_train = np.random.normal(target_function(x_valid, y_valid), sigma) # actual measures from which we want to guess regression parameters
z_valid = np.random.normal(target_function_tests = 3n(x_valid, y_valid), sigma)

# %%
from mpl_toolkits.mplot3d import Axes3D

ax = Axes3D(plt.figure())
ax.scatter( x_valid, y_valid,z_target, c=z_target, marker='.')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-177-dece03ebcca4>:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(plt.figure())
# No handles with labels found to put in legend.

# %%
# Out:
# [0.10896547138690948, 0.10896547138690948]

# %%
list(range(0,0))
# Out:
# []
